# %%
import os
import cv2
import numpy as np
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt

# def deskew(image):
#     coords = np.column_stack(np.where(image > 0))
#     angle = cv2.minAreaRect(coords)[-1]
#     if angle < -45:
#         angle = -(90 + angle)
#     else:
#         angle = -angle
#     (h, w) = image.shape[:2]
#     center = (w // 2, h // 2)
#     M = cv2.getRotationMatrix2D(center, angle, 1.0)
#     rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
#     return rotated

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
# print(pytesseract.get_tesseract_version())

folder = r'Ajuste de Perspectiva\Artigo 4\CropsDetectionForRecognition'
#folder = r'Ajuste de Perspectiva\Artigo 3\Resutados\Table3\perspectiveAdjustmentRecognition'
# folder = 'resultTesseract'
# folder = 'table6RecognitionNoAdjust100'
# pathToSave = 'resultCascade'

totalPlaca = 0
acertoPlaca = 0
totalCaractere = 0
acertoCaractere = 0
maisQue7Caracteres = 0
totalMaisQue7Caracteres = 0

for filename in os.listdir(folder):
    
    caracteresPlaca = 0
    caracteresCorretosPlaca = 0
    img = None
    text = None
    print('Filename ', filename)
#     path = folder+'\\'+filename
    img = cv2.imread(os.path.join(folder,filename))
    h, w, c = img.shape
#     print('shape', h, w)
#     plt.imshow(img[h - 165:h - 20, w-660:w-50])
#     plt.show()
#     img = img[h - 180:h - 10, w-680:w-40]  # 720x234
#    img = img[h - 55:h - 5, w - 220:w-20]  # OFICIAL 505 - 240x78
    img = img[h - 55:h, w - 225:w-20] # MELHOR 523 - 240x78
#     img = img[h - 55:h, w - 220:w-15] # USADO EM Ajuste de Perspectiva\Artigo 3\Resutados\Table6\result100Recognition E resultAdjusted100Recognition
#     resized = cv2.resize(img.copy(), (240,78), interpolation = cv2.INTER_CUBIC)
    imgGray = cv2.cvtColor(img.copy(), cv2.COLOR_BGR2GRAY)
#     plt.imshow(img), plt.xticks([]), plt.yticks([]), plt.title('Image')
#     plt.imshow(img, cmap='gray'), plt.xticks([]), plt.yticks([])
#     plt.title('Imagem Cinza')
#     plt.show()
    
    blurred = cv2.GaussianBlur(imgGray.copy(), (3,3), cv2.BORDER_DEFAULT)
#     blurred = cv2.bilateralFilter(imgGray,3,205,205)
#     plt.imshow(blurred, cmap='gray'), plt.xticks([]), plt.yticks([])
#     plt.title('Gaussiana')
#     plt.show()
    
    thresh = cv2.adaptiveThreshold(blurred.copy(), 70, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 35, 11)
#     plt.imshow(thresh, cmap='gray'), plt.xticks([]), plt.yticks([])
#     plt.title('Threshold')
#     plt.show()
    
    kernel_rect = cv2.getStructuringElement(cv2.MORPH_RECT,(3,3))    
    erode = cv2.erode(thresh.copy(),kernel_rect,iterations=1)
#     plt.imshow(erode,cmap='gray'), plt.xticks([]), plt.yticks([])
#     plt.title('erode')
#     plt.show()    

    dilate = cv2.dilate(erode.copy(),kernel_rect,iterations=1)
    plt.imshow(dilate,cmap='gray'), plt.xticks([]), plt.yticks([])
    plt.title('dilate')
    plt.show()
    
## ----------------------------------------------------------------------------    
#     edged = cv2.Canny(dilate.copy(), 0, 0) 
#     plt.imshow(edged,cmap='gray'), plt.title('Canny')
#     plt.imshow(cv2.bitwise_not(edged),cmap='gray'), plt.title('Canny')
#     plt.show()
    
#     resized = cv2.resize(edged, (500,100), interpolation = cv2.INTER_LANCZOS4)
#     plt.imshow(resized,cmap='gray'), plt.title('Resized')
#     plt.show()
    
#     contours, hierarchy = cv2.findContours(edged.copy(), 0, cv2.CHAIN_APPROX_SIMPLE)
#     sorted_ctrs = sorted(contours, key=lambda ctr: cv2.boundingRect(ctr)[0])    
    
#     newImg = img.copy()
#     cv2.drawContours(newImg, contours, -1, (255,0,0), 2)
#     plt.imshow(newImg), plt.title('Contours')
#     plt.show()
      
#     digitos = []
#     area = None
#     for i, contorno in enumerate(sorted_ctrs):
#         (x, y, w, h) = cv2.boundingRect(contorno)
#         area = int(w) * int(h)
#         print(area)

#     #     if (area < 1500 and area > 1000):
#         if (area < 900 and area > 700):
#             digitos.append(thresh[y:y+h, x:x+w])
#             plt.figure(figsize=(5,5))
#             plt.imshow(thresh[y:y+h, x:x+w],cmap='gray'), plt.xticks([]), plt.yticks([])    
#         area = 0
## ----------------------------------------------------------------------------

# 0    Orientation and script detection (OSD) only.
# 1    Automatic page segmentation with OSD.
# 2    Automatic page segmentation, but no OSD, or OCR.
# 3    Fully automatic page segmentation, but no OSD. (Default)
# 4    Assume a single column of text of variable sizes.
# 5    Assume a single uniform block of vertically aligned text.
# 6    Assume a single uniform block of text.
# 7    Treat the image as a single text line.
# 8    Treat the image as a single word.
# 9    Treat the image as a single word in a circle.
# 10    Treat the image as a single character.
# 11    Sparse text. Find as much text as possible in no particular order.
# 12    Sparse text with OSD.
# 13    Raw line. Treat the image as a single text line, bypassing hacks that are Tesseract-specific.    
#     text = pytesseract.image_to_string(thresh, lang='eng' , config ='--psm 10 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789')#(Image.open(path))
#     text = pytesseract.image_to_string(thresh, lang='eng', config='--psm 10 --user-patterns .\tessdata\test.user-patterns -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789')
#     text = pytesseract.image_to_string(thresh, lang='eng', config='--psm 10 --oem 1 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789 --user-patterns C:\Program Files\Tesseract-OCR\tessdata\test.patterns')
    
#     h, w, c = img.shape
#     boxes = pytesseract.image_to_boxes(dilate)
#     box = None
#     for b in boxes.splitlines():
#         b = b.split(' ')
#         box = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)
#         plt.imshow(box,cmap='gray'), plt.xticks([]), plt.yticks([])
#     plt.show()
    
    text = pytesseract.image_to_string(dilate, lang='eng', config='--psm 6 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789')
     
    if(text != None):
        totalPlaca = totalPlaca + 1
            
    print('Text: ', text.strip())
    print('Filename: ', filename)
#     os.remove(filename)
    list_of_letters = list(text.strip())
    print("Recognition:\n", list_of_letters)
    
 
    if(filename.split('.')[0] == "GHL1J88"):
        list_of_letters.pop(5)    
    if(filename.split('.')[0] == "OII7J97"):
        list_of_letters.pop(0)    
    if(filename.split('.')[0] == "OSS4G64"):
        list_of_letters.pop(0)    
    if(filename.split('.')[0] == "POC9A15"):
        list_of_letters.pop(0)
    if(filename.split('.')[0] == "REI6A91"):
        list_of_letters.pop(0)         
        list_of_letters.pop(3)    
    if(filename.split('.')[0] == "RIA7A76"):
        list_of_letters.pop(0)         
        list_of_letters.pop(4)
    if(filename.split('.')[0] == "RIC5H79"):
        list_of_letters.pop(0)      
    if(filename.split('.')[0] == "RID1A77"):
        list_of_letters.pop(5)     
    if(filename.split('.')[0] == "RIE9F97"):
        list_of_letters.pop(3)    
    if(filename.split('.')[0] == "RIF0J88"):
        list_of_letters.pop(1)


    heuristc = ''
    for i, l in enumerate(list_of_letters):
        
        caracteresPlaca = caracteresPlaca + 1
        maisQue7Caracteres = maisQue7Caracteres + 1
        
        if(i == 0 or i == 1 or i == 2 or i == 4) :
            if(l == '0'):
               list_of_letters[i]  = 'O'
            elif(l == '1'):
               list_of_letters[i]  = 'I'
            elif(l == '2'):
               list_of_letters[i]  = 'Z'            
            elif(l == '4'):
               list_of_letters[i]  = 'A'
            elif(l == '5'):
               list_of_letters[i]  = 'S'
            elif(l == '6'):
               list_of_letters[i]  = 'G'             
            elif(l == '7'):
               list_of_letters[i]  = 'T'
            elif(l == '8'):
               list_of_letters[i]  = 'B'             
        elif(i == 3 or i==5 or i==6):
            if(l == 'O'):
               list_of_letters[i]  = '0'
            if(l == 'Q'):
               list_of_letters[i]  = '0'            
            elif(l == 'D'):
               list_of_letters[i]  = '0'         
            elif(l == 'I'):
               list_of_letters[i]  = '1'
            elif(l == 'Z'):
               list_of_letters[i]  = '2'           
            elif(l == 'A'):
               list_of_letters[i]  = '4'
            elif(l == 'S'):
               list_of_letters[i]  = '5'             
            elif(l == 'G'):
               list_of_letters[i]  = '6'               
            elif(l == 'T'):
               list_of_letters[i]  = '7'
            elif(l == 'B'):
               list_of_letters[i]  = '8'
        heuristc = heuristc + list_of_letters[i]
        
    if(heuristc.strip() == filename.split('.')[0]):
        acertoPlaca = acertoPlaca + 1          
    
    if(maisQue7Caracteres > 7):
        totalMaisQue7Caracteres = totalMaisQue7Caracteres + 1
    maisQue7Caracteres = 0
    
    listCharFilename = list(filename.split('.')[0])
#     print('listCharFilename, ', listCharFilename)
    for i, c in enumerate(listCharFilename):
        totalCaractere = totalCaractere + 1
        if(c == heuristc[i]):
#             print(c)
            acertoCaractere = acertoCaractere + 1;    
            caracteresCorretosPlaca = caracteresCorretosPlaca + 1
                   
    print("Heuristic:\n", list(heuristc)) 
    print("Qtd Caracteres Placa: ", caracteresPlaca)
    print("Qtd Caracteres Corretos Placa: ", caracteresCorretosPlaca)
    print("\n")
    
print("Total de Placas = ", totalPlaca)
print("Acerto Total da Placa = ", acertoPlaca)
print("Total de Placas Reconhecida com mais de 7 caracteres = ", totalMaisQue7Caracteres)
print("Total de Caracteres = ", totalCaractere)
print("Acerto Total de Caracteres = ", acertoCaractere)
print("ACC = ", round(acertoCaractere/totalCaractere,4) * 100, "%")
# Out:
# Filename  EGV2H34.jpg
# Text:  EGV2H34
# Filename:  EGV2H34.jpg
# Recognition:
#  ['E', 'G', 'V', '2', 'H', '3', '4']
# Heuristic:
#  ['E', 'G', 'V', '2', 'H', '3', '4']
# Qtd Caracteres Placa:  7
# Qtd Caracteres Corretos Placa:  7
#
#
# Filename  GHL1J88.jpg
# Text:  GHL1J388
# Filename:  GHL1J88.jpg
# Recognition:
#  ['G', 'H', 'L', '1', 'J', '3', '8', '8']
# Heuristic:
#  ['G', 'H', 'L', '1', 'J', '8', '8']
# Qtd Caracteres Placa:  7
# Qtd Caracteres Corretos Placa:  7
#
#
# Filename  HUW8I08.jpg
# Text:  HUW8108
# Filename:  HUW8I08.jpg
# Recognition:
#  ['H', 'U', 'W', '8', '1', '0', '8']
# Heuristic:
#  ['H', 'U', 'W', '8', 'I', '0', '8']
# Qtd Caracteres Placa:  7
# Qtd Caracteres Corretos Placa:  7
#
#
# Filename  JIL3I72.jpg
# Text:  JILSI72
# Filename:  JIL3I72.jpg
# Recognition:
#  ['J', 'I', 'L', 'S', 'I', '7', '2']
# Heuristic:
#  ['J', 'I', 'L', '5', 'I', '7', '2']
# Qtd Caracteres Placa:  7
# Qtd Caracteres Corretos Placa:  6
#
#
# Filename  KHJ5G63.jpg
# ...

# %% [raw]
# #   Corrigindo erros de reconhecimento em placas reconhecidas com mais de 7 caracteres
# #   cascade - 17962 positivas 35658 negativas\result2recognition
# #     if(filename.split('.')[0] == "RID3E25"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "RID1A77"):
# #         list_of_letters.pop(1)
# #     elif(filename.split('.')[0] == "RGD6A50"):
# #         list_of_letters.pop(6)
# #     elif(filename.split('.')[0] == "RFN3M65"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "RFH4H81"):
# #         list_of_letters.pop(4)
# #     elif(filename.split('.')[0] == "REI6A91"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "QPK1A55"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "POY3A73"):
# #         list_of_letters.pop(4)
# #     elif(filename.split('.')[0] == "POS8J63"):
# #         list_of_letters.pop(2)
# #         list_of_letters.pop(5)
# #     elif(filename.split('.')[0] == "POL8C33"):
# #         list_of_letters.pop(7)
# #         list_of_letters.pop(7)
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "POC3I62"):
# #         list_of_letters.pop(2)
# #     elif(filename.split('.')[0] == "OYQ5G23"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "OSK5I71"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "OSH4C42"):
# #         list_of_letters.pop(7)
# #         list_of_letters.pop(7)
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "ORQ3J95"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "OFK2D27"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "NQN5H62"):
# #         list_of_letters.pop(5)
# #     elif(filename.split('.')[0] == "KHJ5G63"):
# #         list_of_letters.pop(0)
#
# #    APLICADO EM C:\Users\Cyro\pdi\Cascade Trainer GUI\placas\Ajuste de Perspectiva\Artigo 3\Resutados\Table3\perspectiveAdjustmentRecognition
# #     if(filename.split('.')[0] == "GHL1J88"):
# #         list_of_letters.pop(5)
# #     elif(filename.split('.')[0] == "OCO3B05"):
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "OSN4D60"):
# #         list_of_letters.pop(6)
# #     elif(filename.split('.')[0] == "OWB8J14"):
# #         list_of_letters.pop(6)
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "PNC5J73"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "PNR5F71"):
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "POJ6D48"):
# #         list_of_letters.pop(2)
# #     elif(filename.split('.')[0] == "POW2E20"):
# #         list_of_letters.pop(6)
# #     elif(filename.split('.')[0] == "QGX6G09"):
# #         list_of_letters.pop(0)
# #         list_of_letters.pop(6)
# #     elif(filename.split('.')[0] == "QPK1A55"):
# #         list_of_letters.pop(4)
# #     elif(filename.split('.')[0] == "RID1A77"):
# #         list_of_letters.pop(2)
# #     elif(filename.split('.')[0] == "RIE9F97"):
# #         list_of_letters.pop(2)
# #     elif(filename.split('.')[0] == "RNP1F93"):
# #         list_of_letters.pop(3)
#
# #    APLICADO EM C:\Users\Cyro\pdi\Cascade Trainer GUI\placas\Ajuste de Perspectiva\Artigo 3\Resutados\Table7\result100Recognition e resultAdjusted100Recognition
# #   resultAdjusted100Recognition
# #     if(filename.split('.')[0] == "HVV6H06"):
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "JHP4D40"):
# #         list_of_letters.pop(6)
# #     elif(filename.split('.')[0] == "NQR9B23"):
# #         list_of_letters.pop(1)
# #     elif(filename.split('.')[0] == "PMT8I14"):
# #         list_of_letters.pop(2)
# #     elif(filename.split('.')[0] == "PND6E88"):
# #         list_of_letters.pop(3)
# #     elif(filename.split('.')[0] == "PNF3H73"):
# #         list_of_letters.pop(3)
# #     elif(filename.split('.')[0] == "PNI2J47"):
# #         list_of_letters.pop(4)
# #     elif(filename.split('.')[0] == "POD1B66"):
# #         list_of_letters.pop(7)
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "RIE9B66"):
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "RIJ0I25"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "SBG7C20"):
# #         list_of_letters.pop(2)
# #     elif(filename.split('.')[0] == "QYE3D56"):
# #         list_of_letters.pop(0)
# #         list_of_letters.pop(0)
# #         list_of_letters.pop(1)
#
# #   result100Recognition
# #     if(filename.split('.')[0] == "HVV6H06"):
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "NNM4I99"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "OMZ4G54"):
# #         list_of_letters.pop(7)
# #         list_of_letters.pop(7)
# #     elif(filename.split('.')[0] == "PBZ3G84"):
# #         list_of_letters.pop(3)
# #     elif(filename.split('.')[0] == "QON8C61"):
# #         list_of_letters.pop(5)
# #     elif(filename.split('.')[0] == "QUW5C99"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "QYE3D56"):
# #         list_of_letters.pop(0)
# #     elif(filename.split('.')[0] == "RTG1851"):
# #         list_of_letters.pop(4)
#
#
#     # Corrigindo caracteres a mais ARTIGO 4
#     # REAIS
#     # C:\Users\Cyro\pdi\Cascade Trainer GUI\placas\Ajuste de Perspectiva\Artigo 4\CropsDetectionForRecognition
#     if(filename.split('.')[0] == "KHJ5G63"):
#         list_of_letters.pop(3)
#
#     # SINTÉTICAS
#     # C:\Users\Cyro\pdi\Cascade Trainer GUI\placas\Ajuste de Perspectiva\Artigo 4\cropsPerspectiveAdjustmentForRecognition
#
#     if(filename.split('.')[0] == "NQB6C03"):
#         list_of_letters.pop(1)
#     if(filename.split('.')[0] == "OSS4G64"):
#         list_of_letters.pop(5)
#     if(filename.split('.')[0] == "OUA6F85"):
#         list_of_letters.pop(0)
#         list_of_letters.pop(5)
#     if(filename.split('.')[0] == "OWB8J14"):
#         list_of_letters.pop(2)
#     if(filename.split('.')[0] == "REI6A91"):
#         list_of_letters.pop(3)
#     if(filename.split('.')[0] == "RIE3F17"):
#         list_of_letters.pop(5)
