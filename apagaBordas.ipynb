# %%
import os
import cv2
import numpy as n
import pandas as pd
import pytesseract
import matplotlib.pyplot as plt
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
folder = 'teste'

for filename in os.listdir(folder):
    img = cv2.imread(os.path.join(folder,filename))
    h, w, c = img.shape
    img = img[h - 55:h - 5, w - 220:w-20]
    
    imgGray = cv2.cvtColor(img.copy(), cv2.COLOR_BGR2GRAY)
    thresh = cv2.adaptiveThreshold(imgGray.copy(), 70, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 35, 11)
    h, w, c = img.shape

## BOUNDING BOX DE CADA CARACTERE
#     boxes = pytesseract.image_to_boxes(thresh)
#     box = None
#     for b in boxes.splitlines():
#         b = b.split(' ')
#         box = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)
#         plt.imshow(box,cmap='gray'), plt.xticks([]), plt.yticks([])
#     plt.show()

## BOUNDING BOX DO TEXTO
    boxes = pytesseract.image_to_boxes(thresh, lang="eng", config="--psm 8", output_type=pytesseract.Output.STRING)
    print(boxes)
    for b in boxes:#.splitlines():
        print('BOX - ',b[0])
#     box = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)
#     plt.imshow(box,cmap='gray'), plt.xticks([]), plt.yticks([])
#     plt.show()
# Out:
# J 0 11 38 50 0
# I 42 12 60 49 0
# L 67 11 88 49 0
# S 94 10 115 48 0
# I 120 10 137 47 0
# 7 145 8 166 46 0
# 2 172 0 200 50 0
#
# BOX -  J
# BOX -
# BOX -  0
# BOX -
# BOX -  1
# BOX -  1
# BOX -
# BOX -  3
# BOX -  8
# BOX -
# BOX -  5
# BOX -  0
# BOX -
# BOX -  0
# BOX -
#
# BOX -  I
# BOX -
# BOX -  4
# BOX -  2
# BOX -
# BOX -  1
# BOX -  2
# BOX -
# BOX -  6
# BOX -  0
# BOX -
# BOX -  4
# BOX -  9
# BOX -
# BOX -  0
# BOX -
#
# BOX -  L
# BOX -
# BOX -  6
# BOX -  7
# BOX -
# BOX -  1
# BOX -  1
# BOX -
# BOX -  8
# BOX -  8
# BOX -
# BOX -  4
# BOX -  9
# BOX -
# BOX -  0
# BOX -
#
# BOX -  S
# BOX -
# BOX -  9
# BOX -  4
# BOX -
# BOX -  1
# BOX -  0
# BOX -
# BOX -  1
# BOX -  1
# BOX -  5
# BOX -
# BOX -  4
# BOX -  8
# BOX -
# BOX -  0
# BOX -
#
# BOX -  I
# BOX -
# BOX -  1
# BOX -  2
# BOX -  0
# BOX -
# BOX -  1
# BOX -  0
# BOX -
# BOX -  1
# BOX -  3
# BOX -  7
# BOX -
# BOX -  4
# BOX -  7
# BOX -
# BOX -  0
# BOX -
#
# BOX -  7
# BOX -
# BOX -  1
# BOX -  4
# ...
